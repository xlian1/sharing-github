# %%
from simple_salesforce import Salesforce
import pandas as pd
import numpy as np

# %%
sf = Salesforce(username='evelynl@accelentertainment.com', password='eell_2358', security_token='n5A25EGpQEhIbBBw7zp2PkoP')

# %%
pd.DataFrame(sf.query("SELECT id,AccountNumber,ShippingCity FROM Account")['records'])
# Out:
#                                              attributes                  Id  \
# 0     {'type': 'Account', 'url': '/services/data/v38...  0011I000006UrqCQAS
# 1     {'type': 'Account', 'url': '/services/data/v38...  0011I000006UrqDQAS
# 2     {'type': 'Account', 'url': '/services/data/v38...  0011I000006UrqEQAS
# 3     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2gNQAR
# 4     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2gOQAR
# 5     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2gcQAB
# 6     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2gdQAB
# 7     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2mUQAR
# 8     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2tfQAB
# 9     {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2tgQAB
# 10    {'type': 'Account', 'url': '/services/data/v38...  0011I00000Ux2u9QAB
# ...
